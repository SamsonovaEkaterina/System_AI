# %% [markdown]
# # Практическая работа №2
# ## Тема: «Операции с данными»
# ### Выполнила студентка: ПКТб-21-1 Самсонова Екатерина Юрьевна
# #### ВАРИАНТ: 17

# %% [markdown]
# #### Задание 1.  Создать Series s1 и s2 по картинке

# %% [markdown]
# ![image.png](attachment:image.png)![image-2.png](attachment:image-2.png)

# %%
import pandas as pd
import numpy as np

# %%
apples = pd.Series([3, 2, 0, 1])

# %%
apples
# Out:
# 0    3
# 1    2
# 2    0
# 3    1
# dtype: int64

# %%
oranges = pd.Series([0, 3, 7, 2])

# %%
oranges
# Out:
# 0    0
# 1    3
# 2    7
# 3    2
# dtype: int64

# %% [markdown]
# #### Задание 2. Создать DataFrame df1 по картинке

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
mtrx = np.array([[3, 0], [2, 3], [0, 7], [1, 2]])

# %%
columns = ['apples', 'oranges']

# %%
df1 = pd.DataFrame(mtrx, columns=columns)

# %%
df1
# Out:
#    apples  oranges
# 0       3        0
# 1       2        3
# 2       0        7
# 3       1        2

# %% [markdown]
# #### Задание 3. Загрузить ваш DataSet

# %%
cybersecurity_attacks = pd.read_excel('cybersecurity_attacks.xlsx', sheet_name = 'cybersecurity_attacks')

# %%
cybersecurity_attacks
# Out:
#                 Timestamp Source IP Address Destination IP Address  \
# 0     2023-05-30 06:33:58     103.216.15.12           84.9.164.252
# 1     2020-08-26 07:08:30    78.199.217.198         66.191.137.154
# 2     2022-11-13 08:23:25      63.79.210.48          198.219.82.17
# 3     2023-07-02 10:38:46               NaN        101.228.192.255
# 4     2023-07-16 13:11:07     71.166.185.76        189.243.174.238
# ...                   ...               ...                    ...
# 39995 2023-10-10 11:59:52     14.102.21.108           109.198.45.7
# 39996 2023-10-10 11:59:52     14.102.21.108           109.198.45.7
# 39997 2023-10-10 11:59:52     14.102.21.108           109.198.45.7
# 39998 2023-10-10 11:59:52     14.102.21.108           109.198.45.7
# 39999 2023-10-10 11:59:52     14.102.21.108           109.198.45.7
#
#        Source Port  Destination Port Protocol  Packet Length Packet Type  \
# 0          31225.0           17616.0     ICMP          503.0        Data
# ...

# %% [markdown]
# #### Задание 4. Показать первые 10 записей вашего DataFrame

# %%
cybersecurity_attacks.head(10)
# Out:
#             Timestamp Source IP Address Destination IP Address  Source Port  \
# 0 2023-05-30 06:33:58     103.216.15.12           84.9.164.252      31225.0
# 1 2020-08-26 07:08:30    78.199.217.198         66.191.137.154      17245.0
# 2 2022-11-13 08:23:25      63.79.210.48          198.219.82.17      16811.0
# 3 2023-07-02 10:38:46               NaN        101.228.192.255      20018.0
# 4 2023-07-16 13:11:07     71.166.185.76        189.243.174.238       6131.0
# 5 2022-10-28 13:14:27     198.102.5.160        147.190.155.133          NaN
# 6 2022-05-16 17:55:43     97.253.103.59           77.16.101.53      26562.0
# 7 2023-02-12 07:13:17      11.48.99.245                    NaN      34489.0
# 8 2023-06-27 11:02:56     49.32.208.167           72.202.237.9      56296.0
# 9 2021-08-15 22:29:04               NaN         160.88.194.172      37918.0
#
#    Destination Port Protocol  Packet Length Packet Type Traffic Type  \
# ...

# %% [markdown]
# #### Задание 5. Показать последние 10 записей вашего DataFrame

# %%
cybersecurity_attacks.tail(10)
# Out:
#                 Timestamp Source IP Address Destination IP Address  \
# 39990 2022-03-17 12:32:16    149.46.211.219           62.75.28.249
# 39991 2020-11-14 05:41:54    66.200.132.243           88.211.51.78
# 39992 2023-10-10 11:59:52     14.102.21.108           109.198.45.7
# 39993 2023-10-10 11:59:52     14.102.21.108           109.198.45.7
# 39994 2023-10-10 11:59:52     14.102.21.108           109.198.45.7
# 39995 2023-10-10 11:59:52     14.102.21.108           109.198.45.7
# 39996 2023-10-10 11:59:52     14.102.21.108           109.198.45.7
# 39997 2023-10-10 11:59:52     14.102.21.108           109.198.45.7
# 39998 2023-10-10 11:59:52     14.102.21.108           109.198.45.7
# 39999 2023-10-10 11:59:52     14.102.21.108           109.198.45.7
#
#        Source Port  Destination Port Protocol  Packet Length Packet Type  \
# 39990      58709.0            2951.0      TCP          227.0        Data
# 39991       8125.0           25130.0     ICMP           81.0     Control
# ...

# %% [markdown]
# #### Задание 7. Показать случайные 10 строк из вашего DataFrame

# %%
cybersecurity_attacks.sample(10)
# Out:
#                 Timestamp Source IP Address Destination IP Address  \
# 36725 2023-02-24 21:40:34     221.206.123.1        190.232.108.161
# 10046 2023-10-02 19:15:12      164.4.215.81         145.172.15.234
# 7722  2021-04-27 23:55:52      106.9.168.49         208.225.163.23
# 23384 2023-04-09 02:52:56     14.216.144.54         149.119.12.213
# 3943  2021-09-15 21:50:16     93.64.171.118        183.184.203.195
# 39621 2022-06-19 02:10:49      15.52.246.63         223.190.200.36
# 13740 2021-06-02 09:02:32      112.232.64.2          58.153.137.53
# 19730 2022-01-20 09:57:24   175.252.248.175          42.17.177.207
# 10031 2020-04-10 05:48:24    187.125.253.22         150.66.218.179
# 28002 2022-02-10 08:40:08     152.29.30.245        155.167.218.238
#
#        Source Port  Destination Port Protocol  Packet Length Packet Type  \
# 36725      32543.0            4459.0     ICMP         1223.0     Control
# 10046      32153.0           51256.0      TCP         1485.0     Control
# ...

# %% [markdown]
# #### Задание 8. Показать типы данных для каждого столбца в DataFrame

# %%
cybersecurity_attacks.dtypes
# Out:
# Timestamp                 datetime64[ns]
# Source IP Address                 object
# Destination IP Address            object
# Source Port                      float64
# Destination Port                 float64
# Protocol                          object
# Packet Length                    float64
# Packet Type                       object
# Traffic Type                      object
# Payload Data                      object
# Malware Indicators                object
# Anomaly Scores                   float64
# Alerts/Warnings                   object
# Attack Type                       object
# Attack Signature                  object
# Action Taken                      object
# Severity Level                    object
# User Information                  object
# Device Information                object
# Network Segment                   object
# Geo-location Data                 object
# Proxy Information                 object
# Firewall Logs                     object
# ...

# %% [markdown]
# #### Задание 9. Показать информацию о DataFrame, включая количество непропущенных значений, типы данных

# %%
cybersecurity_attacks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 25 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Timestamp               40000 non-null  datetime64[ns]
#  1   Source IP Address       39995 non-null  object
#  2   Destination IP Address  39995 non-null  object
#  3   Source Port             39995 non-null  float64
#  4   Destination Port        39996 non-null  float64
#  5   Protocol                39999 non-null  object
#  6   Packet Length           39998 non-null  float64
#  7   Packet Type             39999 non-null  object
#  8   Traffic Type            40000 non-null  object
#  9   Payload Data            40000 non-null  object
#  10  Malware Indicators      19989 non-null  object
#  11  Anomaly Scores          40000 non-null  float64
#  12  Alerts/Warnings         19943 non-null  object
#  13  Attack Type             40000 non-null  object
# ...

# %% [markdown]
# #### Задание 10. Показать статистический анализ числовых столбцов, включая среднее, стандартное отклонение, минимум и максимум о DataFrame

# %%
cybersecurity_attacks.describe()
# Out:
#                            Timestamp   Source Port  Destination Port  \
# count                          40000  39995.000000      39996.000000
# mean   2021-11-22 03:43:17.004950016  32982.256457      33161.492874
# min              2020-01-01 00:43:27   1027.000000       1024.000000
# 25%       2020-12-12 10:19:34.500000  16858.000000      17106.000000
# 50%       2021-11-21 14:23:13.500000  32880.000000      33023.000000
# 75%       2022-10-30 08:48:10.500000  48956.000000      49310.000000
# max              2023-10-11 19:34:23  65530.000000      65535.000000
# std                              NaN  18560.092449      18573.601546
#
#        Packet Length  Anomaly Scores
# count   39998.000000    40000.000000
# mean      781.473649       50.119437
# min        64.000000        0.000000
# 25%       421.000000       25.160000
# 50%       782.000000       50.360000
# 75%      1143.000000       75.012500
# max      1500.000000      100.000000
# std       415.958569       28.847832

# %% [markdown]
# #### Задание 11. Показать Возвращает DataFrame с булевыми значениями, указывающими на пропущенные значения

# %%
cybersecurity_attacks.isna()
# Out:
#        Timestamp  Source IP Address  Destination IP Address  Source Port  \
# 0          False              False                   False        False
# 1          False              False                   False        False
# 2          False              False                   False        False
# 3          False               True                   False        False
# 4          False              False                   False        False
# ...          ...                ...                     ...          ...
# 39995      False              False                   False        False
# 39996      False              False                   False        False
# 39997      False              False                   False        False
# 39998      False              False                   False        False
# 39999      False              False                   False        False
#
#        Destination Port  Protocol  Packet Length  Packet Type  Traffic Type  \
# ...

# %% [markdown]
# #### Задание 12. Заменить пропущенные значения значением value в DataFrame

# %%
cybersecurity_attacks.fillna('value')
# Out:
#                 Timestamp Source IP Address Destination IP Address  \
# 0     2023-05-30 06:33:58     103.216.15.12           84.9.164.252
# 1     2020-08-26 07:08:30    78.199.217.198         66.191.137.154
# 2     2022-11-13 08:23:25      63.79.210.48          198.219.82.17
# 3     2023-07-02 10:38:46             value        101.228.192.255
# 4     2023-07-16 13:11:07     71.166.185.76        189.243.174.238
# ...                   ...               ...                    ...
# 39995 2023-10-10 11:59:52     14.102.21.108           109.198.45.7
# 39996 2023-10-10 11:59:52     14.102.21.108           109.198.45.7
# 39997 2023-10-10 11:59:52     14.102.21.108           109.198.45.7
# 39998 2023-10-10 11:59:52     14.102.21.108           109.198.45.7
# 39999 2023-10-10 11:59:52     14.102.21.108           109.198.45.7
#
#       Source Port Destination Port Protocol Packet Length Packet Type  \
# 0         31225.0          17616.0     ICMP         503.0        Data
# ...

# %% [markdown]
# #### Задание 13. Заменить пропущенные значения значением среднего в DataFrame

# %%
cybersecurity_attacks.fillna(50.119437)
# Out:
#                 Timestamp Source IP Address Destination IP Address  \
# 0     2023-05-30 06:33:58     103.216.15.12           84.9.164.252
# 1     2020-08-26 07:08:30    78.199.217.198         66.191.137.154
# 2     2022-11-13 08:23:25      63.79.210.48          198.219.82.17
# 3     2023-07-02 10:38:46         50.119437        101.228.192.255
# 4     2023-07-16 13:11:07     71.166.185.76        189.243.174.238
# ...                   ...               ...                    ...
# 39995 2023-10-10 11:59:52     14.102.21.108           109.198.45.7
# 39996 2023-10-10 11:59:52     14.102.21.108           109.198.45.7
# 39997 2023-10-10 11:59:52     14.102.21.108           109.198.45.7
# 39998 2023-10-10 11:59:52     14.102.21.108           109.198.45.7
# 39999 2023-10-10 11:59:52     14.102.21.108           109.198.45.7
#
#        Source Port  Destination Port   Protocol  Packet Length Packet Type  \
# 0          31225.0           17616.0       ICMP          503.0        Data
# ...

# %% [markdown]
# #### Задание 14. Заменить пропущенные значения значением медианны в DataFrame

# %%
cybersecurity_attacks.iloc[20000]
# Out:
# Timestamp                                               2022-09-27 12:19:42
# Source IP Address                                            178.94.230.105
# Destination IP Address                                        28.69.232.119
# Source Port                                                         60174.0
# Destination Port                                                    24440.0
# Protocol                                                                UDP
# Packet Length                                                         359.0
# Packet Type                                                            Data
# Traffic Type                                                            DNS
# Payload Data              Iusto soluta hic quisquam.\nMolestiae magnam a...
# Malware Indicators                                             IoC Detected
# Anomaly Scores                                                        91.75
# ...

# %%
cybersecurity_attacks.fillna(91.75)
# Out:
#                 Timestamp Source IP Address Destination IP Address  \
# 0     2023-05-30 06:33:58     103.216.15.12           84.9.164.252
# 1     2020-08-26 07:08:30    78.199.217.198         66.191.137.154
# 2     2022-11-13 08:23:25      63.79.210.48          198.219.82.17
# 3     2023-07-02 10:38:46             91.75        101.228.192.255
# 4     2023-07-16 13:11:07     71.166.185.76        189.243.174.238
# ...                   ...               ...                    ...
# 39995 2023-10-10 11:59:52     14.102.21.108           109.198.45.7
# 39996 2023-10-10 11:59:52     14.102.21.108           109.198.45.7
# 39997 2023-10-10 11:59:52     14.102.21.108           109.198.45.7
# 39998 2023-10-10 11:59:52     14.102.21.108           109.198.45.7
# 39999 2023-10-10 11:59:52     14.102.21.108           109.198.45.7
#
#        Source Port  Destination Port Protocol  Packet Length Packet Type  \
# 0          31225.0           17616.0     ICMP          503.0        Data
# ...

# %% [markdown]
# #### Задание 15. Заменить пропущенные значения значением максимальным в DataFrame

# %%
cybersecurity_attacks.fillna(100.000000)
# Out:
#                 Timestamp Source IP Address Destination IP Address  \
# 0     2023-05-30 06:33:58     103.216.15.12           84.9.164.252
# 1     2020-08-26 07:08:30    78.199.217.198         66.191.137.154
# 2     2022-11-13 08:23:25      63.79.210.48          198.219.82.17
# 3     2023-07-02 10:38:46             100.0        101.228.192.255
# 4     2023-07-16 13:11:07     71.166.185.76        189.243.174.238
# ...                   ...               ...                    ...
# 39995 2023-10-10 11:59:52     14.102.21.108           109.198.45.7
# 39996 2023-10-10 11:59:52     14.102.21.108           109.198.45.7
# 39997 2023-10-10 11:59:52     14.102.21.108           109.198.45.7
# 39998 2023-10-10 11:59:52     14.102.21.108           109.198.45.7
# 39999 2023-10-10 11:59:52     14.102.21.108           109.198.45.7
#
#        Source Port  Destination Port Protocol  Packet Length Packet Type  \
# 0          31225.0           17616.0     ICMP          503.0        Data
# ...

# %% [markdown]
# #### Задание 16. Заменить пропущенные значения значением минимальным в DataFrame

# %%
cybersecurity_attacks.fillna(0.000000)
# Out:
#                 Timestamp Source IP Address Destination IP Address  \
# 0     2023-05-30 06:33:58     103.216.15.12           84.9.164.252
# 1     2020-08-26 07:08:30    78.199.217.198         66.191.137.154
# 2     2022-11-13 08:23:25      63.79.210.48          198.219.82.17
# 3     2023-07-02 10:38:46               0.0        101.228.192.255
# 4     2023-07-16 13:11:07     71.166.185.76        189.243.174.238
# ...                   ...               ...                    ...
# 39995 2023-10-10 11:59:52     14.102.21.108           109.198.45.7
# 39996 2023-10-10 11:59:52     14.102.21.108           109.198.45.7
# 39997 2023-10-10 11:59:52     14.102.21.108           109.198.45.7
# 39998 2023-10-10 11:59:52     14.102.21.108           109.198.45.7
# 39999 2023-10-10 11:59:52     14.102.21.108           109.198.45.7
#
#        Source Port  Destination Port Protocol  Packet Length Packet Type  \
# 0          31225.0           17616.0     ICMP          503.0        Data
# ...

# %% [markdown]
# #### Задание 17. Показать количество уникальных значений в каждом столбце в DataFrame

# %%
cybersecurity_attacks.nunique()
# Out:
# Timestamp                 39972
# Source IP Address         39970
# Destination IP Address    39970
# Source Port               29744
# Destination Port          29880
# Protocol                      3
# Packet Length              1437
# Packet Type                   2
# Traffic Type                  3
# Payload Data              39975
# Malware Indicators            1
# Anomaly Scores             9826
# Alerts/Warnings               1
# Attack Type                   3
# Attack Signature              2
# Action Taken                  3
# Severity Level                3
# User Information          32374
# Device Information        32088
# Network Segment               3
# Geo-location Data          8723
# Proxy Information         20137
# Firewall Logs                 1
# IDS/IPS Alerts                1
# Log Source                    2
# dtype: int64

# %% [markdown]
# #### Задание 18. Подсчитать количество вхождений каждого уникального значения в столбце в DataFrame

# %%
cybersecurity_attacks.value_counts('Source Port')
# Out:
# Source Port
# 56030.0    17
# 50137.0     8
# 41341.0     6
# 53397.0     5
# 4239.0      5
#            ..
# 25698.0     1
# 25694.0     1
# 25692.0     1
# 25691.0     1
# 32868.0     1
# Name: count, Length: 29744, dtype: int64

# %% [markdown]
# #### Задание 19. Удалить строки с пропущенными значениями в DataFrame

# %%
cybersecurity_attacks.dropna()
# Out:
#                 Timestamp Source IP Address Destination IP Address  \
# 2     2022-11-13 08:23:25      63.79.210.48          198.219.82.17
# 46    2023-05-16 13:01:56    170.211.138.30         172.97.181.148
# 97    2021-10-25 04:23:15   129.189.216.143         197.202.27.160
# 105   2022-10-30 05:51:47      62.75.113.77         216.196.28.158
# 120   2020-03-24 05:59:35    175.197.78.254           78.172.11.97
# ...                   ...               ...                    ...
# 39832 2023-01-15 00:16:35    192.68.130.174           47.59.96.194
# 39887 2022-01-31 14:01:44     185.115.82.22           184.58.72.27
# 39896 2020-09-23 07:09:09     85.96.253.113         78.219.210.210
# 39905 2020-12-30 20:32:48       91.16.73.36          172.76.179.79
# 39956 2022-06-17 02:41:11     205.9.232.102             57.3.168.6
#
#        Source Port  Destination Port Protocol  Packet Length Packet Type  \
# 2          16811.0           53600.0      UDP          306.0     Control
# ...

# %% [markdown]
# #### Задание 20. Показать булевы значения, указывающие на дубликаты строк в DataFrame

# %%
cybersecurity_attacks.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 39995     True
# 39996     True
# 39997     True
# 39998     True
# 39999     True
# Length: 40000, dtype: bool

# %% [markdown]
# #### Задание 21. Удалить дубликаты строк из DataFrame

# %%
cybersecurity_attacks.drop_duplicates()
# Out:
#                 Timestamp Source IP Address Destination IP Address  \
# 0     2023-05-30 06:33:58     103.216.15.12           84.9.164.252
# 1     2020-08-26 07:08:30    78.199.217.198         66.191.137.154
# 2     2022-11-13 08:23:25      63.79.210.48          198.219.82.17
# 3     2023-07-02 10:38:46               NaN        101.228.192.255
# 4     2023-07-16 13:11:07     71.166.185.76        189.243.174.238
# ...                   ...               ...                    ...
# 39988 2021-02-09 03:53:42     160.10.82.152          1.179.113.201
# 39989 2020-02-25 12:10:40     109.15.148.90         136.251.191.39
# 39990 2022-03-17 12:32:16    149.46.211.219           62.75.28.249
# 39991 2020-11-14 05:41:54    66.200.132.243           88.211.51.78
# 39992 2023-10-10 11:59:52     14.102.21.108           109.198.45.7
#
#        Source Port  Destination Port Protocol  Packet Length Packet Type  \
# 0          31225.0           17616.0     ICMP          503.0        Data
# ...

# %% [markdown]
# #### Задание 22. Заменить определенное значения в DataFrame на указанные значения

# %%
cybersecurity_attacks['Traffic Type'] = cybersecurity_attacks['Traffic Type'].replace('HTTP', 'FTP')

# %%
cybersecurity_attacks
# Out:
#                 Timestamp Source IP Address Destination IP Address  \
# 0     2023-05-30 06:33:58     103.216.15.12           84.9.164.252
# 1     2020-08-26 07:08:30    78.199.217.198         66.191.137.154
# 2     2022-11-13 08:23:25      63.79.210.48          198.219.82.17
# 3     2023-07-02 10:38:46     163.42.196.10        101.228.192.255
# 4     2023-07-16 13:11:07     71.166.185.76        189.243.174.238
# ...                   ...               ...                    ...
# 39995 2023-05-26 14:08:42      26.36.109.26         121.100.75.240
# 39996 2023-03-27 00:38:27      17.21.163.81         196.108.134.78
# 39997 2022-03-31 01:45:49     162.35.217.57            98.107.0.15
# 39998 2023-09-22 18:32:38    208.72.233.205         173.79.112.252
# 39999 2023-10-10 11:59:52     14.102.21.108           109.198.45.7
#
#        Source Port  Destination Port Protocol  Packet Length Packet Type  \
# 0          31225.0           17616.0     ICMP            503        Data
# ...

# %% [markdown]
# #### Задание 23. Сохранить DataFrame в формат Excel с именем Practice2_dataset.xlsx

# %% [markdown]
# #### Задание 24. Сохранить DataFrame в формат CSV с именем Practice2_ dataset.CSV

# %% [markdown]
# #### Задание 25. Сохранить DataFrame в формат JSON с именем Practice2_ dataset.json

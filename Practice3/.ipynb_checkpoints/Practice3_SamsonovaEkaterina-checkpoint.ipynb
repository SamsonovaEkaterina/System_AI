# %% [markdown]
# # Практическая работа №3
# ## Тема: «Визуализация данных»
# ### Выполнила студентка: ПКТБ-21-1 Самсонова Екатерина Юрьевна
# #### ВАРИАНТ: 17

# %% [markdown]
# #### Задание 1. Загрузить и данные из файла Dataset_Variants.xlsx, где номер листа ваш вариант

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
My_dataset17 = pd.read_excel('Dataset_Variants.xlsx', sheet_name = '17')

# %% [markdown]
# #### Задание 2. Отобразить данные вашего варианта

# %%
My_dataset17
# Out:
#      X          Y
# 0    1  25.361106
# 1    2   8.233730
# 2    3  66.624710
# 3    4  74.412998
# 4    5  86.148208
# 5    6  44.308496
# 6    7  37.599892
# 7    8  53.591481
# 8    9  71.672463
# 9   10   2.039161
# 10  11  34.079693
# 11  12  47.079726
# 12  13  61.414642
# 13  14  27.878531
# 14  15  40.368110
# 15  16  38.572625
# 16  17  51.265619
# 17  18  46.640241
# 18  19  39.180736
# 19  20  32.969939
# 20  21 -11.407263
# 21  22  13.203322
# 22  23  40.932167
# 23  24  87.923996
# 24  25  20.644240
# 25  26  63.633212
# 26  27  41.572622
# 27  28  88.124654
# 28  29  43.583742
# 29  30  61.474100
# 30  31  37.117462
# 31  32  41.681875
# 32  33  72.090376
# 33  34  70.989887
# 34  35  43.905391
# 35  36  38.627792
# 36  37  70.800030
# 37  38  25.239575
# 38  39  41.948187
# 39  40  55.891877
# 40  41  50.113801
# 41  42  64.998761
# 42  43  62.978745
# 43  44  80.442720
# 44  45  66.412969
# 45  46  28.917458
# 46  47  80.786850
# 47  48  29.410063
# 48  49  66.282712
# 49  50   9.449724

# %% [markdown]
# #### Задание 3. Визуализировать данные в стиле Столбчатые диаграммы (подписать оси)

# %%
X_array = My_dataset17['X'].values
Y_array = My_dataset17['Y'].values
plt.bar(X_array, Y_array)
plt.title("Столбчатая диаграмма")
plt.xlabel('X')
plt.ylabel('Y')
# Out:
# Text(0, 0.5, 'Y')

# %% [markdown]
# #### Задание 4. Визуализировать данные в стиле Точечный график (подписать оси)

# %%
plt.scatter(X_array, Y_array)
plt.title("Точечный график")
plt.xlabel('X')
plt.ylabel('Y')
plt.grid()

# %% [markdown]
# #### Задание 5. Отрицательные значение по Y заменить значением по модулю

# %%
My_dataset17['Y'] = My_dataset17['Y'].apply(lambda x: abs(x))

# %% [markdown]
# #### Задание 6. Отобразить изменённые данные вашего варианта

# %%
My_dataset17
# Out:
#      X          Y
# 0    1  25.361106
# 1    2   8.233730
# 2    3  66.624710
# 3    4  74.412998
# 4    5  86.148208
# 5    6  44.308496
# 6    7  37.599892
# 7    8  53.591481
# 8    9  71.672463
# 9   10   2.039161
# 10  11  34.079693
# 11  12  47.079726
# 12  13  61.414642
# 13  14  27.878531
# 14  15  40.368110
# 15  16  38.572625
# 16  17  51.265619
# 17  18  46.640241
# 18  19  39.180736
# 19  20  32.969939
# 20  21  11.407263
# 21  22  13.203322
# 22  23  40.932167
# 23  24  87.923996
# 24  25  20.644240
# 25  26  63.633212
# 26  27  41.572622
# 27  28  88.124654
# 28  29  43.583742
# 29  30  61.474100
# 30  31  37.117462
# 31  32  41.681875
# 32  33  72.090376
# 33  34  70.989887
# 34  35  43.905391
# 35  36  38.627792
# 36  37  70.800030
# 37  38  25.239575
# 38  39  41.948187
# 39  40  55.891877
# 40  41  50.113801
# 41  42  64.998761
# 42  43  62.978745
# 43  44  80.442720
# 44  45  66.412969
# 45  46  28.917458
# 46  47  80.786850
# 47  48  29.410063
# 48  49  66.282712
# 49  50   9.449724

# %% [markdown]
# #### Задание 7. Визуализировать изменённые данные вашего варианта в стиле Столбчатые диаграммы (подписать оси, столбцы зеленого цвета)

# %%
X_array = My_dataset17['X'].values
Y_array = My_dataset17['Y'].values
plt.bar(X_array, Y_array, color = 'g')
plt.title("Столбчатая диаграмма измененных данных")
plt.xlabel('X')
plt.ylabel('Y')
# Out:
# Text(0, 0.5, 'Y')

# %% [markdown]
# #### Задание 8. Визуализировать изменённые данные вашего варианта в стиле Точечный график (подписать оси, столбцы зеленого цвета)

# %%
plt.scatter(X_array, Y_array, color = 'g')
plt.title("Точечный график измененных данных")
plt.xlabel('X')
plt.ylabel('Y')
plt.grid()

# %% [markdown]
# #### Задание 9. Визуализировать изменённые данные вашего варианта в стиле Линейный график (подписать оси, цвет, стиль линии изменить на ваше усмотрение)

# %%
line = plt.plot(X_array, Y_array, color = 'r')
plt.setp(line, linestyle = '-.')
plt.title("Линейный график измененных данных")
plt.xlabel('X')
plt.ylabel('Y')
plt.grid()

# %% [markdown]
# #### Задание 10. Визуализировать изменённые данные вашего варианта в стиле Линейный график с маркером (подписать оси, цвет, стиль линии и тип маркера изменить на ваше усмотрение)

# %%
line = plt.plot(X_array, Y_array, color = 'm', marker='o')
plt.setp(line, linestyle = '--')
plt.title("Линейный график измененных данных с маркером")
plt.xlabel('X')
plt.ylabel('Y')
plt.grid()

# %% [markdown]
# #### Задание 11. Визуализировать изменённые данные вашего варианта в стиле Цветовое распределение

# %%
plt.imshow(My_dataset17)

# %% [markdown]
# #### Задание 12. Загрузить и данные из файла Dataset_Variants.xlsx c номером листа 10000, где номер столбца Y ваш вариант

# %%
My_dataset_10000_17 = pd.read_excel('Dataset_Variants.xlsx', usecols=[0, 17], sheet_name = '10000')

# %% [markdown]
# #### Задание 13. Отобразить данные вашего варианта

# %%
My_dataset_10000_17
# Out:
#           X          Y17
# 0         1  1019.721710
# 1         2  1022.997938
# 2         3  1015.090421
# 3         4   957.635055
# 4         5   984.753231
# ...     ...          ...
# 9995   9996  1002.677780
# 9996   9997   995.458865
# 9997   9998   957.731234
# 9998   9999  1014.543303
# 9999  10000  1004.541135
#
# [10000 rows x 2 columns]

# %% [markdown]
# #### Задание 14. Визуализировать данные в стиле Столбчатые диаграммы (подписать оси)

# %%
X_array = My_dataset_10000_17['X'].values
Y_array = My_dataset_10000_17['Y17'].values
plt.bar(X_array, Y_array)
plt.title("Столбчатая диаграмма")
plt.xlabel('X')
plt.ylabel('Y')
# Out:
# Text(0, 0.5, 'Y')

# %% [markdown]
# #### Задание 15. Визуализировать данные в стиле Точечный график (подписать оси)

# %%
plt.scatter(X_array, Y_array)
plt.title("Точечный график")
plt.xlabel('X')
plt.ylabel('Y')
plt.grid()

# %% [markdown]
# #### Задание 16. Визуализировать данные вашего варианта в стиле Столбчатые диаграммы (подписать оси, столбцы зеленого цвета)

# %%
plt.bar(X_array, Y_array, color = 'g')
plt.title("Столбчатая диаграмма зеленого цвета")
plt.xlabel('X')
plt.ylabel('Y')
# Out:
# Text(0, 0.5, 'Y')

# %% [markdown]
# #### Задание 17. Визуализировать данные вашего варианта в стиле Точечный график (подписать оси, столбцы красного цвета)

# %%
plt.scatter(X_array, Y_array, color = 'r')
plt.title("Точечный график красного цвета")
plt.xlabel('X')
plt.ylabel('Y')
plt.grid()

# %% [markdown]
# #### Задание 18. Визуализировать данные вашего варианта в стиле Линейный график (подписать оси, цвет, стиль линии изменить на ваше усмотрение)

# %%
line = plt.plot(X_array, Y_array, color = 'c')
plt.setp(line, linestyle = '--')
plt.title("Линейный график")
plt.xlabel('X')
plt.ylabel('Y')
plt.grid()

# %% [markdown]
# #### Задание
# 35 2023-09-23 19:07:33    203.171.62.228            27.5.94.221      41615.0
# 36 2022-05-22 03:10:27   115.120.220.179          72.56.150.150      34512.0
# 37 2022-06-04 20:45:18      140.29.40.43           61.57.62.247      28975.0
# 38 2022-12-29 23:42:12     76.128.95.185         142.92.111.242      46111.0
# 39 2023-03-14 07:27:32      118.23.216.0          109.17.204.56       5032.0
#
#     Destination Port Protocol  Packet Length Packet Type Traffic Type  \
# 0            17616.0     ICMP          503.0        Data         HTTP
# 1            48166.0     ICMP         1174.0        Data         HTTP
# 2            53600.0      UDP          306.0     Control         HTTP
# 3            32534.0      UDP          385.0        Data         HTTP
# 4            26646.0      NaN         1462.0        Data          DNS
# 5            52805.0      UDP         1423.0        Data         HTTP
# 6            17416.0      TCP          379.0        Data          DNS
# 7            20396.0     ICMP         1022.0        Data          DNS
# 8            20857.0      TCP            NaN     Control          FTP
# 9            50039.0      UDP          224.0        Data         HTTP
# 10           35006.0     ICMP          661.0        Data         HTTP
# 11               NaN      TCP          281.0     Control         HTTP
# 12           38048.0     ICMP           64.0     Control          DNS
# 13           10845.0     ICMP         1341.0        Data         HTTP
# 14           35243.0      UDP            NaN        Data          DNS
# 15           21176.0      TCP          425.0        Data          DNS
# 16            5259.0      TCP          838.0     Control         HTTP
# 17           50583.0      TCP          969.0        Data         HTTP
# 18           26783.0      TCP          124.0     Control          DNS
# 19           17595.0      TCP          461.0        Data         HTTP
# 20           37634.0     ICMP          845.0     Control          DNS
# 21            1757.0      UDP          410.0     Control          DNS
# 22           46077.0      UDP         1425.0        Data          DNS
# 23           28015.0      UDP          118.0        Data         HTTP
# 24           27107.0      TCP         1386.0     Control          DNS
# 25           31279.0      UDP          433.0     Control          DNS
# 26           15521.0      UDP          531.0     Control          FTP
# 27           33023.0      TCP          282.0     Control         HTTP
# 28           43307.0     ICMP         1487.0     Control         HTTP
# 29           11594.0      UDP          563.0     Control          DNS
# 30           49527.0      TCP         1313.0     Control         HTTP
# 31           61136.0      UDP          350.0     Control         HTTP
# 32           47900.0      TCP          373.0        Data          DNS
# 33           16459.0     ICMP         1155.0     Control          DNS
# 34            8138.0      TCP          521.0        Data          FTP
# 35           15184.0     ICMP         1346.0        Data          FTP
# 36           40467.0      UDP         1311.0     Control          DNS
# 37            5960.0      UDP          117.0     Control          FTP
# 38           15554.0      TCP         1271.0     Control         HTTP
# 39            1068.0      TCP          308.0     Control          DNS
#
#                                          Payload Data  ... Action Taken  \
# 0   Qui natus odio asperiores nam. Optio nobis ius...  ...       Logged
# 1   Aperiam quos modi officiis veritatis rem. Omni...  ...      Blocked
# 2   Perferendis sapiente vitae soluta. Hic delectu...  ...      Ignored
# 3   Totam maxime beatae expedita explicabo porro l...  ...      Blocked
# 4   Odit nesciunt dolorem nisi iste iusto. Animi v...  ...      Blocked
# 5   Repellat quas illum harum fugit incidunt exerc...  ...       Logged
# 6   Qui numquam inventore repellat ratione fugit o...  ...      Ignored
# 7   Amet libero optio quidem praesentium libero. E...  ...       Logged
# 8   Veritatis nihil amet atque molestias aperiam m...  ...      Blocked
# 26            High   Renee Ramachandran
# 27             Low           Anahi Apte
# 28             Low           Faiyaz Som
# 29          Medium         Kavya Shenoy
# 30             Low         Tushar Borra
# 31          Medium         Mannat Goyal
# 32          Medium        Tushar Shenoy
# 33             Low           Jiya Devan
# 34            High         Yasmin Balan
# 35             Low     Bhavin Chaudhari
# 36          Medium        Aniruddh Dani
# 37             Low            Eva Dalal
# 38          Medium         Nehmat Joshi
# 39          Medium             Ojas Ray
#
#                                    Device Information Network Segment  \
# 0   Mozilla/5.0 (compatible; MSIE 8.0; Windows NT ...       Segment A
# 1   Mozilla/5.0 (compatible; MSIE 8.0; Windows NT ...       Segment B
# 2   Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...       Segment C
# 3   Mozilla/5.0 (Macintosh; PPC Mac OS X 10_11_5; ...       Segment B
# 4   Mozilla/5.0 (compatible; MSIE 5.0; Windows NT ...       Segment C
# 5   Opera/8.58.(X11; Linux i686; nl-NL) Presto/2.9...       Segment C
# 6   Opera/9.24.(X11; Linux i686; fa-IR) Presto/2.9...       Segment A
# 7   Mozilla/5.0 (Macintosh; U; PPC Mac OS X 10_7_6...       Segment A
# 8   Mozilla/5.0 (Macintosh; U; PPC Mac OS X 10_5_8...       Segment B
# 9   Mozilla/5.0 (Windows; U; Windows NT 6.0) Apple...       Segment A
# 10  Mozilla/5.0 (iPod; U; CPU iPhone OS 4_3 like M...       Segment B
# 11  Opera/8.38.(X11; Linux x86_64; pt-BR) Presto/2...       Segment B
# 12  Opera/8.54.(Windows NT 6.0; tg-TJ) Presto/2.9....       Segment B
# 13  Mozilla/5.0 (compatible; MSIE 7.0; Windows NT ...       Segment C
# 14  Mozilla/5.0 (X11; Linux i686; rv:1.9.7.20) Gec...       Segment B
# 15  Opera/8.85.(X11; Linux x86_64; sk-SK) Presto/2...       Segment C
# 16  Opera/8.72.(Windows NT 6.1; ia-FR) Presto/2.9....       Segment B
# 17  Mozilla/5.0 (X11; Linux i686) AppleWebKit/536....       Segment B
# 18  Mozilla/5.0 (compatible; MSIE 6.0; Windows NT ...       Segment C
# 19  Mozilla/5.0 (iPhone; CPU iPhone OS 12_4_8 like...       Segment B
# 20  Mozilla/5.0 (Macintosh; U; PPC Mac OS X 10_11_...       Segment A
# 21  Mozilla/5.0 (Windows; U; Windows NT 5.01) Appl...       Segment C
# 22  Mozilla/5.0 (compatible; MSIE 5.0; Windows 95;...       Segment A
# 23  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...       Segment A
# 24  Mozilla/5.0 (compatible; MSIE 5.0; Windows NT ...       Segment C
# 25  Mozilla/5.0 (Windows; U; Windows 98; Win 9x 4....       Segment C
# 26  Mozilla/5.0 (Windows; U; Windows NT 5.1) Apple...       Segment C
# 27  Mozilla/5.0 (compatible; MSIE 7.0; Windows NT ...       Segment A
# 28  Opera/8.62.(X11; Linux i686; ru-UA) Presto/2.9...       Segment C
# 29  Mozilla/5.0 (X11; Linux i686) AppleWebKit/533....       Segment C
# 30  Mozilla/5.0 (iPad; CPU iPad OS 3_1_3 like Mac ...       Segment C
# 31  Mozilla/5.0 (Windows; U; Windows NT 5.0) Apple...       Segment A
# 32  Opera/9.76.(X11; Linux i686; ha-NG) Presto/2.9...       Segment B
# 33  Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10_1...       Segment B
# 34  Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like ...       Segment C
# 35  Mozilla/5.0 (Android 7.1; Mobile; rv:22.0) Gec...       Segment A
# 36  Mozilla/5.0 (iPhone; CPU iPhone OS 5_1_1 like ...       Segment C
# 37  Mozilla/5.0 (Android 1.0; Mobile; rv:45.0) Gec...       Segment B
# 38  Opera/8.48.(Windows NT 6.0; mt-MT) Presto/2.9....       Segment C
# 39  Mozilla/5.0 (iPhone; CPU iPhone OS 4_2_1 like ...       Segment A
#
#                Geo-location Data Proxy Information Firewall Logs  \
# 0             Jamshedpur, Sikkim      150.9.97.135      Log Data
# 1             Bilaspur, Nagaland               NaN      Log Data
# 2              Bokaro, Rajasthan    114.133.48.179      Log Data
# 3             Jaunpur, Rajasthan               NaN           NaN
# 4             Anantapur, Tripura     149.6.110.119           NaN
# 5          Aurangabad, Meghalaya               NaN           NaN
# 6                 Eluru, Manipur               NaN      Log Data
# 7       Phagwara, Andhra Pradesh      192.31.159.5      Log Data
# 8                Ambala, Tripura               NaN      Log Data
# 9                Rampur, Mizoram    87.128.245.244           NaN
# 10              Gangtok, Haryana     29.161.99.247           NaN
# 11              Nandyal, Mizoram               NaN           NaN
# 12               Silchar, Kerala               NaN      Log Data
# 13              Gudivada, Odisha      59.131.15.72           NaN
# 14          Silchar, Maharashtra    155.121.88.187           NaN
# 15             Bhiwandi, Tripura               NaN      Log Data
# 16            Solapur, Telangana               NaN      Log Data
# 17            Darbhanga, Mizoram     20.252.145.34      Log Data
# 18             Rampur, Rajasthan               NaN           NaN
# 19       Ahmednagar, Uttarakhand    106.203.136.99      Log Data
# 20        Kharagpur, West Bengal     71.135.96.151      Log Data
# 21     Tadepalligudem, Rajasthan               NaN      Log Data
# 22                 Gaya, Gujarat     169.32.12.215           NaN
# 23      Chandrapur, Chhattisgarh     50.108.129.83           NaN
# 24           Guntakal, Rajasthan               NaN      Log Data
# 25                Giridih, Assam               NaN      Log Data
# 26       Katihar, Andhra Pradesh     183.242.33.16      Log Data
# 27  Shahjahanpur, Andhra Pradesh     180.52.47.153           NaN
# 28       Solapur, Madhya Pradesh               NaN      Log Data
# 29         Coimbatore, Telangana               NaN      Log Data
# 30        Serampore, West Bengal               NaN      Log Data
# 31           Gudivada, Karnataka               NaN      Log Data
# 32              Nellore, Tripura               NaN      Log Data
# 33                 Ludhiana, Goa     40.171.118.90           NaN
# 34              Orai, Tamil Nadu               NaN      Log Data
# 35        Jaunpur, Uttar Pradesh               NaN           NaN
# 36   Hubli–Dharwad, Chhattisgarh               NaN           NaN
# 37                Sagar, Mizoram               NaN           NaN
# 38          Medininagar, Gujarat               NaN           NaN
# 39          Ichalkaranji, Sikkim    153.251.24.124           NaN
#
#    IDS/IPS Alerts Log Source
# 0             NaN     Server
# 1             NaN   Firewall
# 2      Alert Data   Firewall
# 3      Alert Data   Firewall
# 4      Alert Data   Firewall
# 5             NaN     Server
# 6             NaN     Server
# 7      Alert Data   Firewall
# 8      Alert Data     Server
# 9             NaN     Server
# 10            NaN     Server
# 11            NaN   Firewall
# 12     Alert Data     Server
# 13            NaN   Firewall
# 14            NaN   Firewall
# 15            NaN   Firewall
# 16            NaN     Server
# 17     Alert Data   Firewall
# 18            NaN   Firewall
# 19     Alert Data     Server
# 20            NaN   Firewall
# 21     Alert Data     Server
# 22     Alert Data     Server
# 23            NaN   Firewall
# 24            NaN     Server
# 25     Alert Data   Firewall
# 26     Alert Data   Firewall
# 27     Alert Data   Firewall
# 28     Alert Data   Firewall
# 29     Alert Data   Firewall
# 30            NaN   Firewall
# 31     Alert Data   Firewall
# 32     Alert Data     Server
# 33            NaN   Firewall
# 34     Alert Data     Server
# 35     Alert Data     Server
# 36     Alert Data   Firewall
# 37            NaN     Server
# 38     Alert Data   Firewall
# 39            NaN     Server
#
# [40 rows x 25 columns]

# %% [markdown]
# #### Выбранные колонки для визуадизации данных

# %%
my_df = pd.read_excel('cybersecurity_attacks.xlsx', usecols=[0, 12], sheet_name = 'cybersecurity_attacks', nrows=40)

# %%
my_df
# Out:
#      X  Anomaly Scores
# 0    1           28.67
# 1    2           51.50
# 2    3           87.42
# 3    4           15.79
# 4    5            0.52
# 5    6            5.76
# 6    7           31.55
# 7    8           54.05
# 8    9           56.34
# 9   10           16.51
# 10  11           24.91
# 11  12           86.07
# 12  13           74.20
# 13  14           62.14
# 14  15           72.65
# 15  16           91.56
# 16  17           43.83
# 17  18           40.46
# 18  19           44.75
# 19  20           13.19
# 20  21           89.99
# 21  22           86.91
# 22  23           72.25
# 23  24           96.27
# 24  25           67.43
# 25  26           89.86
# 26  27           87.23
# 27  28           44.40
# 28  29           45.42
# 29  30           25.70
# 30  31           69.20
# 31  32           77.06
# 32  33            3.87
# 33  34           25.93
# 34  35           60.57
# 35  36           67.73
# 36  37           75.16
# 37  38           75.46
# 38  39           49.03
# 39  40           85.28

# %% [markdown]
# #### Задание 22. Визуализировать данные вашего скаченного DataSet в стиле Столбчатые диаграммы (подписать оси, заголовок)

# %%
X_array = my_df['X'].values
Y_array = my_df['Anomaly Scores'].values
plt.bar(X_array, Y_array)
plt.title("Столбчатая диаграмма")
plt.xlabel('X')
plt.ylabel('Показатель аномалии атаки')
# Out:
# Text(0, 0.5, 'Показатель аномалии атаки')

# %% [markdown]
# #### Задание 23. Визуализировать данные вашего скаченного DataSet в стиле Точечный график (подписать оси, заголовок)

# %%
X_array = my_df['X'].values
Y_array = my_df['Anomaly Scores'].values
plt.scatter(X_array, Y_array)
plt.title("Точечный график")
plt.xlabel('X')
plt.ylabel('Показатель аномалии атаки')
plt.grid()

# %% [markdown]
# #### Задание 24. Визуализировать данные вашего скаченного DataSet в стиле Столбчатые диаграммы (подписать оси, заголовок, столбцы зеленого цвета)

# %%
X_array = my_df['X'].values
Y_array = my_df['Anomaly Scores'].values
plt.bar(X_array, Y_array, color = 'g')
plt.title("Столбчатая диаграмма")
plt.xlabel('X')
plt.ylabel('Показатель аномалии атаки')
# Out:
# Text(0, 0.5, 'Показатель аномалии атаки')

# %% [markdown]
# #### Задание 25. Визуализировать данные вашего скаченного DataSet  в стиле Точечный график (подписать оси, заголовок, столбцы красного цвета)

# %%
X_array = my_df['X'].values
Y_array = my_df['Anomaly Scores'].values
plt.scatter(X_array, Y_array, color = 'r')
plt.title("Точечный график")
plt.xlabel('X')
plt.ylabel('Показатель аномалии атаки')
plt.grid()

# %% [markdown]
# #### Задание 26. Визуализировать данные вашего скаченного DataSet в стиле Линейный график (подписать оси, заголовок, цвет, стиль линии изменить на ваше усмотрение)

# %%
X_array = my_df['X'].values
Y_array = my_df['Anomaly Scores'].values
line = plt.plot(X_array, Y_array, color = 'c')
plt.setp(line, linestyle = '--')
plt.title("Линейный график")
plt.xlabel('X')
plt.ylabel('Y')
plt.grid()

# %% [markdown]
# #### Задание 27. Визуализировать данные вашего скаченного DataSet в стиле Цветовое распределение

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()


for column in cybersecurity_attacks_scores.columns:
    cybersecurity_attacks_scores[column] = encoder.fit_transform(cybersecurity_attacks_scores[column])


plt.pcolor(my_df)
plt.colorbar()
